# %% [markdown]
# <a href="https://colab.research.google.com/github/LeojTandayu/VDA-CPE031-CPE21S4/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Installation**

# %%
# !pip install pandas

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# # **Matplot Pyplot**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# Draw a line in a diagram from position (1,3) to (8,20)

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 20])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# # **Plotting without a line**
#
# - to plot only the markers, 'o' means 'rings'

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints,ypoints, 'o')
plt.show()

# %% [markdown]
# # **Multiple Points**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints, marker='h')
plt.show()

# %% [markdown]
# # **Format Strings fmt**

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'o:y')
plt.show()

# %% [markdown]
# # **Marker Size**

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:y', ms = 99)
plt.show()

# %% [markdown]
# # **Marker Color**

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:y', ms = 99, mfc = 'b')
plt.show()

# %% [markdown]
# # **Dash Line**

# %%
plt.plot(ypoints, linestyle="--")

# %% [markdown]
# # **Matplot labels and titles**

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", color ='r')
plt.xlabel(" Distance in km")
plt.ylabel("Speed in km/s")
plt.show()

# %% [markdown]
# # **Matplot Grid**

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", color ='r')
plt.xlabel(" Distance in km")
plt.ylabel("Speed in km/s")
plt.grid()
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", color ='r')
plt.xlabel(" Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis = 'x', linestyle='--', linewidth = 1/2)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.subplot (1,2,1)
plt.plot(xpoints,ypoints)
plt.title("Distance Travelled Everyday", color ='r')
plt.xlabel(" Distance in km")
plt.ylabel("Speed in km/s")

xpoints= np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.subplot (1,2,2)
plt.plot(xpoints,ypoints)

plt.title("Kenn Jow", color ='r')
plt.xlabel(" Day/s ")
plt.ylabel(" Boys ")
plt.grid(axis = 'x', linestyle='--', linewidth = 1/2)
plt.show()

# %% [markdown]
# # **Matplot Scatter**

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.scatter(xpoints,ypoints)

xpoints= np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.scatter(xpoints,ypoints)

plt.show()

# %% [markdown]
# # **Matplot Bars**

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["Kenn","Jie","Valleser"])
y=np.array([95, 85, 86])

plt.bar(x,y)
plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
g = np.array([35, 25, 25, 15])
grader = ["Grade 1 =35%", "Grade 2 =25%", "Grade 3 =25%", "Grade 4 =15%"]
plt.pie(g,labels=grader)
plt.legend(labels="Grader")
plt.legend(title = "Grader", labels=grader)
plt.show()

# %% [markdown]
# # **Manual Activity**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1 , 2 , 3 , 4]
y = [10 , 20 , 25 , 30]


plt.plot(x,y)
plt.title("Line Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
x = [1 , 2 , 3 , 4]
y = [10 , 20 , 25 , 30]


plt.scatter(x,y)
plt.title("Scatter Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# # **Histogram**

# %%
data = [1,2,2,3,3,3,4]

plt.hist(data)
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
categories = ['A', 'B', 'C']
values = [5 , 7 , 3]

plt.bar(categories, values)
plt.title("Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # **Box Plot**

# %%
data = [[1.5]*10 +[2]*10 + [3]*10]

plt.boxplot(data)
plt.title("Box Plot")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
labels = ['A', 'B', 'C']
sizes = [40, 30, 30]

plt.pie(sizes, labels=labels)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# # **Part 2**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('genshin_base_data - genshin.xlsx - Original Data(2)(1).csv')
df.head()
# Out:
#   character_name  rarity     region  vision arkhe weapon_type          model  \
# 0         Albedo       5  Mondstadt     Geo   NaN       Sword    Medium Male
# 1      Alhaitham       5     Sumeru  Dendro   NaN       Sword      Tall Male
# 2           Aloy       5        NaN    Cryo   NaN         Bow  Medium Female
# 3          Amber       4  Mondstadt    Pyro   NaN         Bow  Medium Female
# 4   Arataki Itto       5    Inazuma     Geo   NaN    Claymore      Tall Male
#
#         constellation birthday                special_dish  ... hp_1_20  \
# 0  Princeps Cretaceus   13-Sep              Woodland Dream  ...    1030
# 1       Vultur Volans   11-Feb          Ideal Circumstance  ...    1039
# 2         Nora Fortis    4-Apr                 Satiety Gel  ...     848
# 3               Lepus   10-Aug  Outrider's Champion Steak!  ...     793
# 4    Taurus Iracundus    1-Jun           Way of the Strong  ...    1001
#
# ...

# %%
import matplotlib.pyplot as plt


regions = df['region'].value_counts()


plt.pie(regions, labels=regions.index)
plt.title('Distribution of Characters by Region' , color = 'b')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

vision_counts = df['vision'].value_counts()

plt.bar(vision_counts.index, vision_counts.values)
plt.title('Distribution of Characters by Vision')
plt.xlabel('Vision')
plt.ylabel('Number of Characters')
plt.tight_layout()
plt.show()

# %%
weapon_counts = df['weapon_type'].value_counts()

plt.hist(df['weapon_type'], bins=weapon_counts.shape[0], edgecolor='black')
plt.title('Distribution of Characters by Weapon Type')
plt.xlabel('Weapon Type')
plt.ylabel('Number of Characters')
plt.tight_layout()
plt.show()
